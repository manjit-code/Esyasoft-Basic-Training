# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import _kmeans

# %%
df = pd.read_csv("D:\Basic-Training-Class-Activity\Basics_of_Python\dataset\Live.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\HP\AppData\Local\Temp\ipykernel_14696\2360833953.py:1: SyntaxWarning: invalid escape sequence '\B'
#   df = pd.read_csv("D:\Basic-Training-Class-Activity\Basics_of_Python\dataset\Live.csv")
#                               status_id status_type  ... Column3  Column4
# 0      246675545449582_1649696485147474       video  ...     NaN      NaN
# 1      246675545449582_1649426988507757       photo  ...     NaN      NaN
# 2      246675545449582_1648730588577397       video  ...     NaN      NaN
# 3      246675545449582_1648576705259452       photo  ...     NaN      NaN
# 4      246675545449582_1645700502213739       photo  ...     NaN      NaN
# ...                                 ...         ...  ...     ...      ...
# 7045  1050855161656896_1061863470556065       photo  ...     NaN      NaN
# 7046  1050855161656896_1061334757275603       photo  ...     NaN      NaN
# ...

# %%
df.shape
# Out:
# (7050, 16)

# %%
# descriptive analysys
df.info
# Out:
# <bound method DataFrame.info of                               status_id status_type  ... Column3  Column4
# 0      246675545449582_1649696485147474       video  ...     NaN      NaN
# 1      246675545449582_1649426988507757       photo  ...     NaN      NaN
# 2      246675545449582_1648730588577397       video  ...     NaN      NaN
# 3      246675545449582_1648576705259452       photo  ...     NaN      NaN
# 4      246675545449582_1645700502213739       photo  ...     NaN      NaN
# ...                                 ...         ...  ...     ...      ...
# 7045  1050855161656896_1061863470556065       photo  ...     NaN      NaN
# 7046  1050855161656896_1061334757275603       photo  ...     NaN      NaN
# 7047  1050855161656896_1060126464063099       photo  ...     NaN      NaN
# 7048  1050855161656896_1058663487542730       photo  ...     NaN      NaN
# 7049  1050855161656896_1050858841656528       photo  ...     NaN      NaN
#
# [7050 rows x 16 columns]>

# %%
# statistical analysis
df.describe()
# Out:
#        num_reactions  num_comments   num_shares  ...  Column2  Column3  Column4
# count    7050.000000   7050.000000  7050.000000  ...      0.0      0.0      0.0
# mean      230.117163    224.356028    40.022553  ...      NaN      NaN      NaN
# std       462.625309    889.636820   131.599965  ...      NaN      NaN      NaN
# min         0.000000      0.000000     0.000000  ...      NaN      NaN      NaN
# 25%        17.000000      0.000000     0.000000  ...      NaN      NaN      NaN
# 50%        59.500000      4.000000     0.000000  ...      NaN      NaN      NaN
# 75%       219.000000     23.000000     4.000000  ...      NaN      NaN      NaN
# max      4710.000000  20990.000000  3424.000000  ...      NaN      NaN      NaN
#
# [8 rows x 13 columns]

# %%
df.dtypes
# Out:
# status_id            object
# status_type          object
# status_published     object
# num_reactions         int64
# num_comments          int64
# num_shares            int64
# num_likes             int64
# num_loves             int64
# num_wows              int64
# num_hahas             int64
# num_sads              int64
# num_angrys            int64
# Column1             float64
# Column2             float64
# Column3             float64
# Column4             float64
# dtype: object

# %%
duplicate_data = df[df.duplicated()]
duplicate_data
# Out:
#                              status_id status_type  ... Column3  Column4
# 6221  819700534875473_1002372733274918       video  ...     NaN      NaN
# 6222  819700534875473_1001982519980606       photo  ...     NaN      NaN
# 6223  819700534875473_1000607730118085       photo  ...     NaN      NaN
# 6224   819700534875473_999880033524188      status  ...     NaN      NaN
# 6225   819700534875473_998824716963053       photo  ...     NaN      NaN
# 6226   819700534875473_997075427137982      status  ...     NaN      NaN
# 6227   819700534875473_995933077252217       photo  ...     NaN      NaN
# 6228   819700534875473_995839410594917       photo  ...     NaN      NaN
# 6229   819700534875473_995218893990302      status  ...     NaN      NaN
# 6230   819700534875473_993975437447981       photo  ...     NaN      NaN
# 6231   819700534875473_993602007485324      status  ...     NaN      NaN
# 6232   819700534875473_993049450873913       photo  ...     NaN      NaN
# ...

# %%
print('Rows before drop duplicate: ', df.shape)
df_1 = df.drop_duplicates()
print('Rows after drop duplicate: ', df_1.shape)
# Out:
# Rows before drop duplicate:  (7050, 16)
# Rows after drop duplicate:  (6999, 16)

# %%
no_of_null = df_1.isnull().sum()
print(no_of_null)
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             6999
# Column2             6999
# Column3             6999
# Column4             6999
# dtype: int64

# %%
# drop null values columns
print('shape before removing null: ', df_1.shape)
df_2 = df_1.drop(columns={'Column1', 'Column2', 'Column3', 'Column4'})
print('shape after removing null: ', df_2.shape)
# Out:
# shape before removing null:  (6999, 16)
# shape after removing null:  (6999, 12)

# %%
df_2.dtypes
# Out:
# status_id           object
# status_type         object
# status_published    object
# num_reactions        int64
# num_comments         int64
# num_shares           int64
# num_likes            int64
# num_loves            int64
# num_wows             int64
# num_hahas            int64
# num_sads             int64
# num_angrys           int64
# dtype: object

# %%
df_2.describe()
# Out:
#        num_reactions  num_comments  ...     num_sads   num_angrys
# count    6999.000000   6999.000000  ...  6999.000000  6999.000000
# mean      224.994571    225.552079  ...     0.232605     0.110159
# std       452.880746    892.743010  ...     1.481105     0.688582
# min         0.000000      0.000000  ...     0.000000     0.000000
# 25%        17.000000      0.000000  ...     0.000000     0.000000
# 50%        58.000000      4.000000  ...     0.000000     0.000000
# 75%       216.000000     22.000000  ...     0.000000     0.000000
# max      4710.000000  20990.000000  ...    51.000000    31.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ## Find the optimal column (Object type), using which we can make clusters:
#
# #### Try choosing column which has [1,10] unique type values in a column

# %%
# check unique values in 'status_id'
len(df_2['status_id'].unique())

# As it has very large no of unique data.. we cant make cluster using this column
# Out:
# 6997

# %%
# check unique values in 'status_id'
len(df_2['status_type'].unique())

# As it has only 4 type. we can make cluster using this column: We always try to have unique value from [1, 10]
# Out:
# 4

# %%
# So we will use K = 4 USING 'status_type' column
# drop rest object type which are not required

df_3 = df_2.drop(columns={'status_id', 'status_published'})
df_3
# Out:
#      status_type  num_reactions  num_comments  ...  num_hahas  num_sads  num_angrys
# 0          video            529           512  ...          1         1           0
# 1          photo            150             0  ...          0         0           0
# 2          video            227           236  ...          1         0           0
# 3          photo            111             0  ...          0         0           0
# 4          photo            213             0  ...          0         0           0
# ...          ...            ...           ...  ...        ...       ...         ...
# 7045       photo             89             0  ...          0         0           0
# 7046       photo             16             0  ...          1         0           0
# 7047       photo              2             0  ...          0         0           0
# 7048       photo            351            12  ...          0         0           0
# ...

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6999 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    6999 non-null   object
#  1   num_reactions  6999 non-null   int64
#  2   num_comments   6999 non-null   int64
#  3   num_shares     6999 non-null   int64
#  4   num_likes      6999 non-null   int64
#  5   num_loves      6999 non-null   int64
#  6   num_wows       6999 non-null   int64
#  7   num_hahas      6999 non-null   int64
#  8   num_sads       6999 non-null   int64
#  9   num_angrys     6999 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 601.5+ KB

# %%
df_3.describe()
# Out:
#        num_reactions  num_comments  ...     num_sads   num_angrys
# count    6999.000000   6999.000000  ...  6999.000000  6999.000000
# mean      224.994571    225.552079  ...     0.232605     0.110159
# std       452.880746    892.743010  ...     1.481105     0.688582
# min         0.000000      0.000000  ...     0.000000     0.000000
# 25%        17.000000      0.000000  ...     0.000000     0.000000
# 50%        58.000000      4.000000  ...     0.000000     0.000000
# 75%       216.000000     22.000000  ...     0.000000     0.000000
# max      4710.000000  20990.000000  ...    51.000000    31.000000
#
# [8 rows x 9 columns]

# %%
df_3.dtypes
# Out:
# status_type      object
# num_reactions     int64
# num_comments      int64
# num_shares        int64
# num_likes         int64
# num_loves         int64
# num_wows          int64
# num_hahas         int64
# num_sads          int64
# num_angrys        int64
# dtype: object

# %% [markdown]
# 9. Declare future vector(X) and target variable(y)

# %%
X = df_3
y = df_3['status_type']

# %% [markdown]
# 10. Convert categorical variable into integers

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

X['status_type'] = le.fit_transform(X['status_type'])
y = le.transform(y)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6999 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    6999 non-null   int64
#  1   num_reactions  6999 non-null   int64
#  2   num_comments   6999 non-null   int64
#  3   num_shares     6999 non-null   int64
#  4   num_likes      6999 non-null   int64
#  5   num_loves      6999 non-null   int64
#  6   num_wows       6999 non-null   int64
#  7   num_hahas      6999 non-null   int64
#  8   num_sads       6999 non-null   int64
#  9   num_angrys     6999 non-null   int64
# dtypes: int64(10)
# memory usage: 601.5 KB

# %%
X.head()
# Out:
#    status_type  num_reactions  num_comments  ...  num_hahas  num_sads  num_angrys
# 0            3            529           512  ...          1         1           0
# 1            1            150             0  ...          0         0           0
# 2            3            227           236  ...          1         0           0
# 3            1            111             0  ...          0         0           0
# 4            1            213             0  ...          0         0           0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Feature Scaling

# %%
cols = X.columns

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

X = ms.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=[cols])

# %%
X.head()
# Out:
#   status_type num_reactions num_comments  ... num_hahas  num_sads num_angrys
# 0    1.000000      0.112314     0.024393  ...  0.006369  0.019608        0.0
# 1    0.333333      0.031847     0.000000  ...  0.000000  0.000000        0.0
# 2    1.000000      0.048195     0.011243  ...  0.006369  0.000000        0.0
# 3    0.333333      0.023567     0.000000  ...  0.000000  0.000000        0.0
# 4    0.333333      0.045223     0.000000  ...  0.000000  0.000000        0.0
#
# [5 rows x 10 columns]

# %% [markdown]
# 12. K-means model with two clusters

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %% [markdown]
# 13. K-mean cluster center

# %%
kmeans.cluster_centers_
# Out:
# array([[3.46167950e-01, 3.61833423e-02, 7.27812657e-04, 7.13272262e-04,
#         3.57027040e-02, 1.99861691e-03, 2.13215566e-03, 1.16037081e-03,
#         2.63163571e-03, 1.24915717e-03],
#        [9.83564249e-01, 6.92281072e-02, 2.92995889e-02, 3.22130472e-02,
#         6.10062518e-02, 5.16536230e-02, 8.90485655e-03, 1.05300588e-02,
#         8.13397894e-03, 7.82133186e-03]])

# %%
# Low inertia -> better model
kmeans.inertia_
# Out:
# 231.09008425740083

# %% [markdown]
# 14. Check Qulaity of weak classification by the model

# %%
labels = kmeans.labels_

# Check how many of the samples were correctly labeled
correct_labeles = sum(y == labels)

print("Result: %d out of %d samples were correctly labled." % (correct_labeles, y.size))
# Out:
# Result: 63 out of 6999 samples were correctly labled.

# %%
print('Accuracy score:  {0:0.2f}'.format(correct_labeles/float(y.size)))
# Out:
# Accuracy score:  0.01

# %%
15.

# %%
from sklearn.cluster import KMeans
cs = []

# List to store all accuracy value
accuracy = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init = 'k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    cs.append(kmeans.inertia_)
    labels = kmeans.labels_

    # Check how many of the samples were correctly labeled
    correct_labeles = sum(y == labels)
    accuracy.append(correct_labeles/float(y.size))

plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Numbe rof clusters')
plt.ylabel('cs')
plt.show()

# %% [markdown]
# # kink at k = 2

# %%
plt.plot(range(1, 11), accuracy)
plt.title('The Elbow Method')
plt.xlabel('Numbe rof clusters')
plt.ylabel('cs')
plt.show()
