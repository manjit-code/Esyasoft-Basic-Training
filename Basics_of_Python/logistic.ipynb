# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv("D:\Basic-Training-Class-Activity\Basics_of_Python\dataset\candy-data.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\HP\AppData\Local\Temp\ipykernel_13760\366797685.py:1: SyntaxWarning: invalid escape sequence '\B'
#   df = pd.read_csv("D:\Basic-Training-Class-Activity\Basics_of_Python\dataset\candy-data.csv")
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0        0                 1     0    1         0         0.732         0.860
# 1        1                 0     0    1         0         0.604         0.511
# 2        0                 0     0    0         0         0.011         0.116
# 3        0                 0     0    0         0         0.011         0.511
# 4        0                 0     0    0         0         0.906         0.511
# ..     ...               ...   ...  ...       ...           ...           ...
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 0    66.971725
# 1    67.602936
# 2    32.261086
# 3    46.116505
# 4    52.341465
# ..         ...
# 80   45.466282
# 81   39.011898
# 82   44.375519
# 83   41.904308
# 84   49.524113
#
# [85 rows x 13 columns]

# %%
df.shape
# Out:
# (85, 13)

# %%
df.dtypes
# Out:
# competitorname       object
# chocolate             int64
# fruity                int64
# caramel               int64
# peanutyalmondy        int64
# nougat                int64
# crispedricewafer      int64
# hard                  int64
# bar                   int64
# pluribus              int64
# sugarpercent        float64
# pricepercent        float64
# winpercent          float64
# dtype: object

# %%
no_of_duplicates = df[df.duplicated()]

print(f'No of Duplicates: ', no_of_duplicates)
# Out:
# No of Duplicates:  Empty DataFrame
# Columns: [competitorname, chocolate, fruity, caramel, peanutyalmondy, nougat, crispedricewafer, hard, bar, pluribus, sugarpercent, pricepercent, winpercent]
# Index: []

# %%
df = df.drop_duplicates()
df
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                    100 Grand          1       0        1               0
# 1                 3 Musketeers          1       0        0               0
# 2                     One dime          0       0        0               0
# 3                  One quarter          0       0        0               0
# 4                    Air Heads          0       1        0               0
# ..                         ...        ...     ...      ...             ...
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0        0                 1     0    1         0         0.732         0.860
# 1        1                 0     0    1         0         0.604         0.511
# 2        0                 0     0    0         0         0.011         0.116
# 3        0                 0     0    0         0         0.011         0.511
# 4        0                 0     0    0         0         0.906         0.511
# ..     ...               ...   ...  ...       ...           ...           ...
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 0    66.971725
# 1    67.602936
# 2    32.261086
# 3    46.116505
# 4    52.341465
# ..         ...
# 80   45.466282
# 81   39.011898
# 82   44.375519
# 83   41.904308
# 84   49.524113
#
# [85 rows x 13 columns]

# %%
null_data = df.isnull().sum()
print(f'no. of null data: ', null_data)
# Out:
# no. of null data:  competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
df.tail()
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 80                   Twizzlers          0       1        0               0
# 81                    Warheads          0       1        0               0
# 82        Welch's Fruit Snacks          0       1        0               0
# 83  Werther's Original Caramel          0       0        1               0
# 84                    Whoppers          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 80       0                 0     0    0         0         0.220         0.116
# 81       0                 0     1    0         0         0.093         0.116
# 82       0                 0     0    0         1         0.313         0.313
# 83       0                 0     1    0         0         0.186         0.267
# 84       0                 1     0    0         1         0.872         0.848
#
#     winpercent
# 80   45.466282
# 81   39.011898
# 82   44.375519
# 83   41.904308
# 84   49.524113

# %%
from sklearn.model_selection import train_test_split
trainingSet, testSet = train_test_split(df, test_size=0.2)

# %%
train_Df = trainingSet
test_Df= testSet

# %%
train_Df
# Out:
#              competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 84                 Whoppers          1       0        0               0
# 32      Peanut butter M&M's          1       0        0               1
# 36                Milky Way          1       0        1               0
# 51       Reese's Miniatures          1       0        0               1
# 8                Candy Corn          0       0        0               0
# ..                      ...        ...     ...      ...             ...
# 23        Hershey's Krackel          1       0        0               0
# 44                Nik L Nip          0       1        0               0
# 13                     Dots          0       1        0               0
# 72             Super Bubble          0       1        0               0
# 77  Tootsie Roll Snack Bars          1       0        0               0
#
#     nougat  crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 84       0                 1     0    0         1         0.872         0.848
# 32       0                 0     0    0         1         0.825         0.651
# 36       1                 0     0    1         0         0.604         0.651
# 51       0                 0     0    0         0         0.034         0.279
# 8        0                 0     0    0         1         0.906         0.325
# ..     ...               ...   ...  ...       ...           ...           ...
# 23       0                 1     0    1         0         0.430         0.918
# 44       0                 0     0    0         1         0.197         0.976
# 13       0                 0     0    0         1         0.732         0.511
# 72       0                 0     0    0         0         0.162         0.116
# 77       0                 0     0    1         0         0.465         0.325
#
#     winpercent
# 84   49.524113
# 32   71.465050
# 36   73.099556
# 51   81.866257
# 8    38.010963
# ..         ...
# 23   62.284481
# 44   22.445341
# 13   42.272076
# 72   27.303865
# 77   49.653503
#
# [68 rows x 13 columns]

# %%
y = df['chocolate']
x = df.drop(columns={'chocolate', 'competitorname'})

# %%
x_train = train_Df[['fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent', 'pricepercent', 'winpercent']]
y_train = train_Df['chocolate']

x_test = test_Df[['fruity', 'caramel', 'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar', 'pluribus', 'sugarpercent', 'pricepercent', 'winpercent']]
y_test = test_Df['chocolate']

# %%
y_train.value_counts()
# Out:
# chocolate
# 0    41
# 1    27
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# chocolate
# 1    10
# 0     7
# Name: count, dtype: int64

# %%
sns.countplot(x="chocolate", data=train_Df, palette='Blues_d')
plt.show()
plt.savefig('count_plot')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13760\2518554286.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="chocolate", data=train_Df, palette='Blues_d')

# %%
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()

# %%
lgr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lgr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,5))
sns.heatmap(cm, annot = True, cmap='Blues', cbar= False,
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            )

plt.show()

# %%
import sklearn.metrics as metrics 
print('Accuracy', metrics.accuracy_score(y_test, y_pred))
print('Precision', metrics.precision_score(y_test, y_pred))
print('Recall', metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy 1.0
# Precision 1.0
# Recall 1.0
